# %% [markdown]
# # Enunciado

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import pycountry

# %% [markdown]
# ## Preparación de datos (1.0pt)

# %% [markdown]
# Explore el archivo `covid19_confirmados.csv` y utilice la función `pd.read_csv` para importarlo como un `DataFrame` considerando las siguientes indicaciones:
#
# 1. Utilice el nombre de país como índice.
# 1. Elimine las columnas `Lat` y `Long`.
# 1. Use TimeStamps para las columnas asociadas a fechas.
# 1. Reduzca la columna `Province/State`. El DataFrame resultante debe tener los totales a nivel país.

# %%
df = pd.read_csv("./data/covid19_confirmados.csv")
df = df.set_index("Country/Region")
df.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0  \
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  4/1/22  4/2/22
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...  177782  177803  \
# Albania               0        0        0        0  ...  273759  273823
# Algeria               0        0        0        0  ...  265679  265684
# Andorra               0        0        0        0  ...   40024   40024
# Angola                0        0        0        0  ...   99194   99194
#
#                 4/3/22  4/4/22  4/5/22  4/6/22  4/7/22  4/8/22  4/9/22
# Country/Region
# Afghanistan     177827  177897  177932  177974  177974  177974  177974  \
# Albania         273870  273913  274000  274055  274108  274136  274191
# Algeria         265691  265694  265699  265705  265707  265714  265720
# Andorra          40024   40024   40024   40024   40328   40328   40328
# Angola           99194   99194   99194   99194   99194   99194   99194
#
#                 4/10/22
# Country/Region
# Afghanistan      177974
# Albania          274219
# Algeria          265724
# Andorra           40328
# Angola            99194
#
# [5 rows x 813 columns]

# %%
df.shape
# Out:
# (284, 813)

# %%
df = df.drop(["Lat", "Long"], axis=1)
df.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20
# Country/Region
# Afghanistan               NaN        0        0        0        0        0  \
# Albania                   NaN        0        0        0        0        0
# Algeria                   NaN        0        0        0        0        0
# Andorra                   NaN        0        0        0        0        0
# Angola                    NaN        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/1/22  4/2/22
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...  177782  177803  \
# Albania               0        0        0        0  ...  273759  273823
# Algeria               0        0        0        0  ...  265679  265684
# Andorra               0        0        0        0  ...   40024   40024
# Angola                0        0        0        0  ...   99194   99194
#
#                 4/3/22  4/4/22  4/5/22  4/6/22  4/7/22  4/8/22  4/9/22
# Country/Region
# Afghanistan     177827  177897  177932  177974  177974  177974  177974  \
# Albania         273870  273913  274000  274055  274108  274136  274191
# Algeria         265691  265694  265699  265705  265707  265714  265720
# Andorra          40024   40024   40024   40024   40328   40328   40328
# Angola           99194   99194   99194   99194   99194   99194   99194
#
#                 4/10/22
# Country/Region
# Afghanistan      177974
# Albania          274219
# Algeria          265724
# Andorra           40328
# Angola            99194
#
# [5 rows x 811 columns]

# %%
fechas = pd.to_datetime(df.columns[1:], format='%m/%d/%y')
df.columns = ["Province/State"] + list(fechas)
df.head()
# Out:
#                Province/State  2020-01-22 00:00:00  2020-01-23 00:00:00
# Country/Region
# Afghanistan               NaN                    0                    0  \
# Albania                   NaN                    0                    0
# Algeria                   NaN                    0                    0
# Andorra                   NaN                    0                    0
# Angola                    NaN                    0                    0
#
#                 2020-01-24 00:00:00  2020-01-25 00:00:00  2020-01-26 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2020-01-27 00:00:00  2020-01-28 00:00:00  2020-01-29 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2020-01-30 00:00:00  ...  2022-04-01 00:00:00
# Country/Region                       ...
# Afghanistan                       0  ...               177782  \
# Albania                           0  ...               273759
# Algeria                           0  ...               265679
# Andorra                           0  ...                40024
# Angola                            0  ...                99194
#
#                 2022-04-02 00:00:00  2022-04-03 00:00:00  2022-04-04 00:00:00
# Country/Region
# Afghanistan                  177803               177827               177897  \
# Albania                      273823               273870               273913
# Algeria                      265684               265691               265694
# Andorra                       40024                40024                40024
# Angola                        99194                99194                99194
#
#                 2022-04-05 00:00:00  2022-04-06 00:00:00  2022-04-07 00:00:00
# Country/Region
# Afghanistan                  177932               177974               177974  \
# Albania                      274000               274055               274108
# Algeria                      265699               265705               265707
# Andorra                       40024                40024                40328
# Angola                        99194                99194                99194
#
#                 2022-04-08 00:00:00  2022-04-09 00:00:00  2022-04-10 00:00:00
# Country/Region
# Afghanistan                  177974               177974               177974
# Albania                      274136               274191               274219
# Algeria                      265714               265720               265724
# Andorra                       40328                40328                40328
# Angola                        99194                99194                99194
#
# [5 rows x 811 columns]

# %%
df = df.groupby("Country/Region")[df.columns[1:]].sum()
df.head()
# Out:
#                 2020-01-22  2020-01-23  2020-01-24  2020-01-25  2020-01-26
# Country/Region
# Afghanistan              0           0           0           0           0  \
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
#
#                 2020-01-27  2020-01-28  2020-01-29  2020-01-30  2020-01-31
# Country/Region
# Afghanistan              0           0           0           0           0  \
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
#
#                 ...  2022-04-01  2022-04-02  2022-04-03  2022-04-04
# Country/Region  ...
# Afghanistan     ...      177782      177803      177827      177897  \
# Albania         ...      273759      273823      273870      273913
# Algeria         ...      265679      265684      265691      265694
# Andorra         ...       40024       40024       40024       40024
# Angola          ...       99194       99194       99194       99194
#
#                 2022-04-05  2022-04-06  2022-04-07  2022-04-08  2022-04-09
# Country/Region
# Afghanistan         177932      177974      177974      177974      177974  \
# Albania             274000      274055      274108      274136      274191
# Algeria             265699      265705      265707      265714      265720
# Andorra              40024       40024       40328       40328       40328
# Angola               99194       99194       99194       99194       99194
#
#                 2022-04-10
# Country/Region
# Afghanistan         177974
# Albania             274219
# Algeria             265724
# Andorra              40328
# Angola               99194
#
# [5 rows x 810 columns]

# %% [markdown]
# Explore el archivo `population_by_country_2020.csv` y utilice la función `pd.read_csv` de pandas para importarlo como un `DataFrame`. Utilice el nombre de país como índice principal.
#
# Nota: Algunos siglas o nombres podrían no calzar con el `DataFrame` anterior, explore y corrija programaticamente dichos errores.

# %%
df_pop = pd.read_csv("./data/poblacion_mundial2020.csv")
df_pop.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change
# 0                   China         1440297825        0.39 %     5540090  \
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age
# 0              153          9388211       -348399.0        1.7       38  \
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# 4        35 %      2.83 %

# %%
df_pop = df_pop.set_index("Country (or dependency)")
df_pop.head()
# Out:
#                          Population (2020) Yearly Change  Net Change
# Country (or dependency)
# China                           1440297825        0.39 %     5540090  \
# India                           1382345085        0.99 %    13586631
# United States                    331341050        0.59 %     1937734
# Indonesia                        274021604        1.07 %     2898047
# Pakistan                         221612785        2.00 %     4327022
#
#                          Density (P/Km²)  Land Area (Km²)  Migrants (net)
# Country (or dependency)
# China                                153          9388211       -348399.0  \
# India                                464          2973190       -532687.0
# United States                         36          9147420        954806.0
# Indonesia                            151          1811570        -98955.0
# Pakistan                             287           770880       -233379.0
#
#                         Fert. Rate Med. Age Urban Pop % World Share
# Country (or dependency)
# China                          1.7       38        61 %     18.47 %
# India                          2.2       28        35 %     17.70 %
# United States                  1.8       38        83 %      4.25 %
# Indonesia                      2.3       30        56 %      3.51 %
# Pakistan                       3.6       23        35 %      2.83 %

# %%
len(df.index)
# Out:
# 198

# %%
len(df_pop.index)
# Out:
# 235

# %%
for country in df.index:
    if country not in df_pop.index:
        print(f"El pais {country} no está")
# Out:
# El pais Antarctica no está
# El pais Burma no está
# El pais Congo (Brazzaville) no está
# El pais Congo (Kinshasa) no está
# El pais Cote d'Ivoire no está
# El pais Czechia no está
# El pais Diamond Princess no está
# El pais Korea, South no está
# El pais Kosovo no está
# El pais MS Zaandam no está
# El pais Saint Kitts and Nevis no está
# El pais Saint Vincent and the Grenadines no está
# El pais Sao Tome and Principe no está
# El pais Summer Olympics 2020 no está
# El pais Taiwan* no está
# El pais US no está
# El pais West Bank and Gaza no está
# El pais Winter Olympics 2022 no está

# %%
#Antartica no está
#Burma no está
#Congo -> hay 2
#Cote d'Ivoire -> Côte d'Ivoire
#Czechia -> Czech Republic (Czechia)
#Diamond Princess no está (barco)
#Korea, South -> South Korea
#Kosovo no está
#MS Zaandam no está (barco)
#Saint Kitts -> Saint Kitts & Nevis'
#Saint Vincent -> St. Vincent & Grenadines
#Sao Tome and Principe -> Sao Tome & Principe
#Summer Olympics 2020 no está (evento)
#Taiwan* -> Taiwan
#US -> United States
#West Bank and Gaza no está 
#Winter Olympics 2022 no está (evento)
#

# %%
#Para verificar paises en df2
[c for c in df_pop.index if c.startswith("G")]
# Out:
# ['Germany',
#  'Ghana',
#  'Guatemala',
#  'Guinea',
#  'Greece',
#  'Georgia',
#  'Gambia',
#  'Gabon',
#  'Guinea-Bissau',
#  'Guyana',
#  'Guadeloupe',
#  'Guam',
#  'Grenada',
#  'Greenland',
#  'Gibraltar']

# %%
paises = []

# %% [markdown]
# Realice un `merge` de los `DataFrame` anteriores. El objetivo es asignar un valor de `Population` a cada elemento del primer `DataFrame`. Indique las filas donde no se puede realizar el `merge` y luego descártelas de su `DataFrame` final.

# %%
df_pop.head()
# Out:
#                          Population (2020) Yearly Change  Net Change
# Country (or dependency)
# China                           1440297825        0.39 %     5540090  \
# India                           1382345085        0.99 %    13586631
# United States                    331341050        0.59 %     1937734
# Indonesia                        274021604        1.07 %     2898047
# Pakistan                         221612785        2.00 %     4327022
#
#                          Density (P/Km²)  Land Area (Km²)  Migrants (net)
# Country (or dependency)
# China                                153          9388211       -348399.0  \
# India                                464          2973190       -532687.0
# United States                         36          9147420        954806.0
# Indonesia                            151          1811570        -98955.0
# Pakistan                             287           770880       -233379.0
#
#                         Fert. Rate Med. Age Urban Pop % World Share
# Country (or dependency)
# China                          1.7       38        61 %     18.47 %
# India                          2.2       28        35 %     17.70 %
# United States                  1.8       38        83 %      4.25 %
# Indonesia                      2.3       30        56 %      3.51 %
# Pakistan                       3.6       23        35 %      2.83 %

# %%
df.index.name = "Country"
df_pop.index.name = "Country"

# %%
df_merged = pd.merge(df, df_pop[["Population (2020)"]], left_index=True, right_index=True, how="inner")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_merged = pd.merge(df, df_pop[["Population (2020)"]], left_index=True, right_index=True, how="inner")
#
# NameError: name 'pd' is not defined

# %%
df_merged.head()
# Out:
#              2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-28 00:00:00  2020-01-29 00:00:00  2020-01-30 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-31 00:00:00  ...  2022-04-02 00:00:00
# Country                           ...
# Afghanistan                    0  ...               177803  \
# Albania                        0  ...               273823
# Algeria                        0  ...               265684
# Andorra                        0  ...                40024
# Angola                         0  ...                99194
#
#              2022-04-03 00:00:00  2022-04-04 00:00:00  2022-04-05 00:00:00
# Country
# Afghanistan               177827               177897               177932  \
# Albania                   273870               273913               274000
# Algeria                   265691               265694               265699
# Andorra                    40024                40024                40024
# Angola                     99194                99194                99194
#
#              2022-04-06 00:00:00  2022-04-07 00:00:00  2022-04-08 00:00:00
# Country
# Afghanistan               177974               177974               177974  \
# Albania                   274055               274108               274136
# Algeria                   265705               265707               265714
# Andorra                    40024                40328                40328
# Angola                     99194                99194                99194
#
#              2022-04-09 00:00:00  2022-04-10 00:00:00  Population (2020)
# Country
# Afghanistan               177974               177974           39074280
# Albania                   274191               274219            2877239
# Algeria                   265720               265724           43984569
# Andorra                    40328                40328              77287
# Angola                     99194                99194           33032075
#
# [5 rows x 811 columns]

# %% [markdown]
# Repita el procedimiento para los archivos `covid19_recuperados.csv` y `covid19_muertes.csv`.

# %%
df_rec = pd.read_csv("./data/covid19_recuperados.csv")
df_rec = df_rec.set_index("Country/Region")
df_rec.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0  \
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  4/1/22  4/2/22
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...       0       0  \
# Albania               0        0        0        0  ...       0       0
# Algeria               0        0        0        0  ...       0       0
# Andorra               0        0        0        0  ...       0       0
# Angola                0        0        0        0  ...       0       0
#
#                 4/3/22  4/4/22  4/5/22  4/6/22  4/7/22  4/8/22  4/9/22
# Country/Region
# Afghanistan          0       0       0       0       0       0       0  \
# Albania              0       0       0       0       0       0       0
# Algeria              0       0       0       0       0       0       0
# Andorra              0       0       0       0       0       0       0
# Angola               0       0       0       0       0       0       0
#
#                 4/10/22
# Country/Region
# Afghanistan           0
# Albania               0
# Algeria               0
# Andorra               0
# Angola                0
#
# [5 rows x 813 columns]

# %%
df_rec = df_rec.drop(["Lat", "Long"], axis=1)
df_rec.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20
# Country/Region
# Afghanistan               NaN        0        0        0        0        0  \
# Albania                   NaN        0        0        0        0        0
# Algeria                   NaN        0        0        0        0        0
# Andorra                   NaN        0        0        0        0        0
# Angola                    NaN        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/1/22  4/2/22
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...       0       0  \
# Albania               0        0        0        0  ...       0       0
# Algeria               0        0        0        0  ...       0       0
# Andorra               0        0        0        0  ...       0       0
# Angola                0        0        0        0  ...       0       0
#
#                 4/3/22  4/4/22  4/5/22  4/6/22  4/7/22  4/8/22  4/9/22
# Country/Region
# Afghanistan          0       0       0       0       0       0       0  \
# Albania              0       0       0       0       0       0       0
# Algeria              0       0       0       0       0       0       0
# Andorra              0       0       0       0       0       0       0
# Angola               0       0       0       0       0       0       0
#
#                 4/10/22
# Country/Region
# Afghanistan           0
# Albania               0
# Algeria               0
# Andorra               0
# Angola                0
#
# [5 rows x 811 columns]

# %%
fechas = pd.to_datetime(df_rec.columns[1:], format='%m/%d/%y')
df_rec.columns = ["Province/State"] + list(fechas)
df_rec.head()
# Out:
#                Province/State  2020-01-22 00:00:00  2020-01-23 00:00:00
# Country/Region
# Afghanistan               NaN                    0                    0  \
# Albania                   NaN                    0                    0
# Algeria                   NaN                    0                    0
# Andorra                   NaN                    0                    0
# Angola                    NaN                    0                    0
#
#                 2020-01-24 00:00:00  2020-01-25 00:00:00  2020-01-26 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2020-01-27 00:00:00  2020-01-28 00:00:00  2020-01-29 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2020-01-30 00:00:00  ...  2022-04-01 00:00:00
# Country/Region                       ...
# Afghanistan                       0  ...                    0  \
# Albania                           0  ...                    0
# Algeria                           0  ...                    0
# Andorra                           0  ...                    0
# Angola                            0  ...                    0
#
#                 2022-04-02 00:00:00  2022-04-03 00:00:00  2022-04-04 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2022-04-05 00:00:00  2022-04-06 00:00:00  2022-04-07 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2022-04-08 00:00:00  2022-04-09 00:00:00  2022-04-10 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
# [5 rows x 811 columns]

# %%
df_rec = df_rec.groupby("Country/Region")[df_rec.columns[1:]].sum()
df_rec.head()
# Out:
#                 2020-01-22  2020-01-23  2020-01-24  2020-01-25  2020-01-26
# Country/Region
# Afghanistan              0           0           0           0           0  \
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
#
#                 2020-01-27  2020-01-28  2020-01-29  2020-01-30  2020-01-31
# Country/Region
# Afghanistan              0           0           0           0           0  \
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
#
#                 ...  2022-04-01  2022-04-02  2022-04-03  2022-04-04
# Country/Region  ...
# Afghanistan     ...           0           0           0           0  \
# Albania         ...           0           0           0           0
# Algeria         ...           0           0           0           0
# Andorra         ...           0           0           0           0
# Angola          ...           0           0           0           0
#
#                 2022-04-05  2022-04-06  2022-04-07  2022-04-08  2022-04-09
# Country/Region
# Afghanistan              0           0           0           0           0  \
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
#
#                 2022-04-10
# Country/Region
# Afghanistan              0
# Albania                  0
# Algeria                  0
# Andorra                  0
# Angola                   0
#
# [5 rows x 810 columns]

# %%
df_rec_merged = pd.merge(df_rec, df_pop[["Population (2020)"]], left_index=True, right_index=True, how="inner")
df_rec_merged.head()
# Out:
#              2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-28 00:00:00  2020-01-29 00:00:00  2020-01-30 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-31 00:00:00  ...  2022-04-02 00:00:00
# Afghanistan                    0  ...                    0  \
# Albania                        0  ...                    0
# Algeria                        0  ...                    0
# Andorra                        0  ...                    0
# Angola                         0  ...                    0
#
#              2022-04-03 00:00:00  2022-04-04 00:00:00  2022-04-05 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2022-04-06 00:00:00  2022-04-07 00:00:00  2022-04-08 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2022-04-09 00:00:00  2022-04-10 00:00:00  Population (2020)
# Afghanistan                    0                    0           39074280
# Albania                        0                    0            2877239
# Algeria                        0                    0           43984569
# Andorra                        0                    0              77287
# Angola                         0                    0           33032075
#
# [5 rows x 811 columns]

# %%
df_m = pd.read_csv("./data/covid19_muertes.csv")
df_m = df_m.set_index("Country/Region")
df_m.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0  \
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  4/1/22  4/2/22
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    7670    7671  \
# Albania               0        0        0        0  ...    3492    3492
# Algeria               0        0        0        0  ...    6874    6874
# Andorra               0        0        0        0  ...     153     153
# Angola                0        0        0        0  ...    1900    1900
#
#                 4/3/22  4/4/22  4/5/22  4/6/22  4/7/22  4/8/22  4/9/22
# Country/Region
# Afghanistan       7671    7671    7671    7671    7671    7671    7671  \
# Albania           3492    3492    3492    3492    3492    3492    3492
# Algeria           6874    6874    6874    6874    6874    6874    6874
# Andorra            153     153     153     153     153     153     153
# Angola            1900    1900    1900    1900    1900    1900    1900
#
#                 4/10/22
# Country/Region
# Afghanistan        7671
# Albania            3493
# Algeria            6874
# Andorra             153
# Angola             1900
#
# [5 rows x 813 columns]

# %%
df_m = df_m.drop(["Lat", "Long"], axis=1)
df_m.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20
# Country/Region
# Afghanistan               NaN        0        0        0        0        0  \
# Albania                   NaN        0        0        0        0        0
# Algeria                   NaN        0        0        0        0        0
# Andorra                   NaN        0        0        0        0        0
# Angola                    NaN        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/1/22  4/2/22
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    7670    7671  \
# Albania               0        0        0        0  ...    3492    3492
# Algeria               0        0        0        0  ...    6874    6874
# Andorra               0        0        0        0  ...     153     153
# Angola                0        0        0        0  ...    1900    1900
#
#                 4/3/22  4/4/22  4/5/22  4/6/22  4/7/22  4/8/22  4/9/22
# Country/Region
# Afghanistan       7671    7671    7671    7671    7671    7671    7671  \
# Albania           3492    3492    3492    3492    3492    3492    3492
# Algeria           6874    6874    6874    6874    6874    6874    6874
# Andorra            153     153     153     153     153     153     153
# Angola            1900    1900    1900    1900    1900    1900    1900
#
#                 4/10/22
# Country/Region
# Afghanistan        7671
# Albania            3493
# Algeria            6874
# Andorra             153
# Angola             1900
#
# [5 rows x 811 columns]

# %%
fechas = pd.to_datetime(df_m.columns[1:], format='%m/%d/%y')
df_m.columns = [df_m.columns[0]] + list(fechas)
df_m.head()
# Out:
#                Province/State  2020-01-22 00:00:00  2020-01-23 00:00:00
# Country/Region
# Afghanistan               NaN                    0                    0  \
# Albania                   NaN                    0                    0
# Algeria                   NaN                    0                    0
# Andorra                   NaN                    0                    0
# Angola                    NaN                    0                    0
#
#                 2020-01-24 00:00:00  2020-01-25 00:00:00  2020-01-26 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2020-01-27 00:00:00  2020-01-28 00:00:00  2020-01-29 00:00:00
# Country/Region
# Afghanistan                       0                    0                    0  \
# Albania                           0                    0                    0
# Algeria                           0                    0                    0
# Andorra                           0                    0                    0
# Angola                            0                    0                    0
#
#                 2020-01-30 00:00:00  ...  2022-04-01 00:00:00
# Country/Region                       ...
# Afghanistan                       0  ...                 7670  \
# Albania                           0  ...                 3492
# Algeria                           0  ...                 6874
# Andorra                           0  ...                  153
# Angola                            0  ...                 1900
#
#                 2022-04-02 00:00:00  2022-04-03 00:00:00  2022-04-04 00:00:00
# Country/Region
# Afghanistan                    7671                 7671                 7671  \
# Albania                        3492                 3492                 3492
# Algeria                        6874                 6874                 6874
# Andorra                         153                  153                  153
# Angola                         1900                 1900                 1900
#
#                 2022-04-05 00:00:00  2022-04-06 00:00:00  2022-04-07 00:00:00
# Country/Region
# Afghanistan                    7671                 7671                 7671  \
# Albania                        3492                 3492                 3492
# Algeria                        6874                 6874                 6874
# Andorra                         153                  153                  153
# Angola                         1900                 1900                 1900
#
#                 2022-04-08 00:00:00  2022-04-09 00:00:00  2022-04-10 00:00:00
# Country/Region
# Afghanistan                    7671                 7671                 7671
# Albania                        3492                 3492                 3493
# Algeria                        6874                 6874                 6874
# Andorra                         153                  153                  153
# Angola                         1900                 1900                 1900
#
# [5 rows x 811 columns]

# %%
df_m[pd.to_datetime("2nd of April of 2020")]
# Out:
# Country/Region
# Afghanistan              4
# Albania                 16
# Algeria                 86
# Andorra                 15
# Angola                   2
#                         ..
# West Bank and Gaza       1
# Winter Olympics 2022     0
# Yemen                    0
# Zambia                   1
# Zimbabwe                 1
# Name: 2020-04-02 00:00:00, Length: 284, dtype: int64

# %%
df_m = df_m.groupby("Country/Region")[df_m.columns[1:]].sum()
df_m.head()
# Out:
#                 2020-01-22  2020-01-23  2020-01-24  2020-01-25  2020-01-26
# Country/Region
# Afghanistan              0           0           0           0           0  \
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
#
#                 2020-01-27  2020-01-28  2020-01-29  2020-01-30  2020-01-31
# Country/Region
# Afghanistan              0           0           0           0           0  \
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
#
#                 ...  2022-04-01  2022-04-02  2022-04-03  2022-04-04
# Country/Region  ...
# Afghanistan     ...        7670        7671        7671        7671  \
# Albania         ...        3492        3492        3492        3492
# Algeria         ...        6874        6874        6874        6874
# Andorra         ...         153         153         153         153
# Angola          ...        1900        1900        1900        1900
#
#                 2022-04-05  2022-04-06  2022-04-07  2022-04-08  2022-04-09
# Country/Region
# Afghanistan           7671        7671        7671        7671        7671  \
# Albania               3492        3492        3492        3492        3492
# Algeria               6874        6874        6874        6874        6874
# Andorra                153         153         153         153         153
# Angola                1900        1900        1900        1900        1900
#
#                 2022-04-10
# Country/Region
# Afghanistan           7671
# Albania               3493
# Algeria               6874
# Andorra                153
# Angola                1900
#
# [5 rows x 810 columns]

# %%
df_m.columns[1]
# Out:
# Timestamp('2020-01-23 00:00:00')

# %%
df_m.index.name = "Country"
#df2.index.name = "Country"
df_m_merged = pd.merge(df_m, df_pop[["Population (2020)"]], left_index=True, right_index=True, how="inner")
df_m_merged.head()
# Out:
#              2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-28 00:00:00  2020-01-29 00:00:00  2020-01-30 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-31 00:00:00  ...  2022-04-02 00:00:00
# Country                           ...
# Afghanistan                    0  ...                 7671  \
# Albania                        0  ...                 3492
# Algeria                        0  ...                 6874
# Andorra                        0  ...                  153
# Angola                         0  ...                 1900
#
#              2022-04-03 00:00:00  2022-04-04 00:00:00  2022-04-05 00:00:00
# Country
# Afghanistan                 7671                 7671                 7671  \
# Albania                     3492                 3492                 3492
# Algeria                     6874                 6874                 6874
# Andorra                      153                  153                  153
# Angola                      1900                 1900                 1900
#
#              2022-04-06 00:00:00  2022-04-07 00:00:00  2022-04-08 00:00:00
# Country
# Afghanistan                 7671                 7671                 7671  \
# Albania                     3492                 3492                 3492
# Algeria                     6874                 6874                 6874
# Andorra                      153                  153                  153
# Angola                      1900                 1900                 1900
#
#              2022-04-09 00:00:00  2022-04-10 00:00:00  Population (2020)
# Country
# Afghanistan                 7671                 7671           39074280
# Albania                     3492                 3493            2877239
# Algeria                     6874                 6874           43984569
# Andorra                      153                  153              77287
# Angola                      1900                 1900           33032075
#
# [5 rows x 811 columns]

# %%
df_m_merged.head()
# Out:
#              2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-28 00:00:00  2020-01-29 00:00:00  2020-01-30 00:00:00
# Country
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
#
#              2020-01-31 00:00:00  ...  2022-04-02 00:00:00
# Country                           ...
# Afghanistan                    0  ...                 7671  \
# Albania                        0  ...                 3492
# Algeria                        0  ...                 6874
# Andorra                        0  ...                  153
# Angola                         0  ...                 1900
#
#              2022-04-03 00:00:00  2022-04-04 00:00:00  2022-04-05 00:00:00
# Country
# Afghanistan                 7671                 7671                 7671  \
# Albania                     3492                 3492                 3492
# Algeria                     6874                 6874                 6874
# Andorra                      153                  153                  153
# Angola                      1900                 1900                 1900
#
#              2022-04-06 00:00:00  2022-04-07 00:00:00  2022-04-08 00:00:00
# Country
# Afghanistan                 7671                 7671                 7671  \
# Albania                     3492                 3492                 3492
# Algeria                     6874                 6874                 6874
# Andorra                      153                  153                  153
# Angola                      1900                 1900                 1900
#
#              2022-04-09 00:00:00  2022-04-10 00:00:00  Population (2020)
# Country
# Afghanistan                 7671                 7671           39074280
# Albania                     3492                 3493            2877239
# Algeria                     6874                 6874           43984569
# Andorra                      153                  153              77287
# Angola                      1900                 1900           33032075
#
# [5 rows x 811 columns]

# %%
df_m_merged.loc["Chile", pd.to_datetime("22th of January of 2020")]
# Out:
# 0

# %% [markdown]
# ## Análisis global (1.5pt)
#
# Escriba una función que reciba una fecha y que retorne las siguientes series:
#
# 1. Tasa de incidencia: Casos confirmados por 100.000 dividido población total.
# 1. Tasa de recuperación: Casos recuperados por 100.000 dividido población total.
# 1. Tasa de mortalidad: Casos decesos por 100.000 dividido población total.

# %% [markdown]
# Ahora, considerando los siguientes dos puntos temporales:
#
# - 22 de Enero de 2021.
# - 22 de Enero de 2022.
#
# Muestre los nombres y los valores de los 3 países con:
#
# 1. La mayor y menor tasa de incidencia, respectivamente.
# 1. La mayor y menor tasa de recuperación, respectivamente.
# 1. La mayor y menor tasa de mortalidad, respectivamente.
#
# Muestre también la posición de Chile en el ranking.

# %%
# def tasa_inc(fecha):
#     valor_por_pais = df_merged[fecha].sum(axis=1) * 100_000 / df_merged["Population (2020)"]
#     return valor_por_pais

# def tasa_rec(fecha):
#     valor_por_pais = df_rec_merged[fecha].sum(axis=1) * 100_000 / df_rec_merged["Population (2020)"]
#     return valor_por_pais

# def tasa_mort(fecha):
#     valor_por_pais = df_m_merged[fecha].sum(axis=1) * 100_000 / df_m_merged["Population (2020)"]
#     return valor_por_pais

def tasas(fecha):
    tasa_inc=df_merged[fecha].sum(axis=1) * 100_000 / df_merged["Population (2020)"].sum()
    tasa_rec= df_rec_merged[fecha].sum(axis=1) * 100_000 / df_rec_merged["Population (2020)"].sum()
    tasa_mort=df_m_merged[fecha].sum(axis=1) * 100_000 / df_m_merged["Population (2020)"].sum()
    return tasa_inc,tasa_mort,tasa_rec
# def tasa_inc(fecha):
#     fecha = pd.to_datetime(fecha)
#     columna_fecha = df_merged.loc[:, fecha]
#     valor_por_pais = columna_fecha * 100_000
#     valor_por_pais = valor_por_pais.div(df_merged["Population (2020)"])
    
#     return valor_por_pais

# def tasa_rec(fecha):
#     fecha = pd.to_datetime(fecha)
#     columna_fecha = df_rec_merged.loc[:, fecha]
#     valor_por_pais = columna_fecha * 100_000
#     valor_por_pais = valor_por_pais.div(df_rec_merged["Population (2020)"])
    
#     return valor_por_pais


# def tasa_mort(fecha):
#     fecha = pd.to_datetime(fecha)
#     columna_fecha = df_m_merged.loc[:, fecha]
#     valor_por_pais = columna_fecha * 100_000
#     valor_por_pais = valor_por_pais.div(df_m_merged["Population (2020)"])
    
#     return valor_por_pais

# %%
fecha1 = "22th of January of 2021"
fecha2 = "22th of January of 2022"



tasas_inc,tasas_mort,tasas_rec = tasas(pd.date_range(start=fecha1, end=fecha2, freq='D'))
#tasas_rec = tasa_rec(pd.date_range(start=fecha1, end=fecha2, freq='D'))
#tasas_mort = tasa_mort(pd.date_range(start=fecha1, end=fecha2, freq='D'))

tasas_inc_sorted = tasas_inc.sort_values()
tasas_rec_sorted = tasas_rec.sort_values()
tasas_mort_sorted = tasas_mort.sort_values()

# %%
pd.date_range(start=fecha1, end=fecha2, freq='D')
# Out:
# DatetimeIndex(['2021-01-22', '2021-01-23', '2021-01-24', '2021-01-25',
#                '2021-01-26', '2021-01-27', '2021-01-28', '2021-01-29',
#                '2021-01-30', '2021-01-31',
#                ...
#                '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-16',
#                '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-22'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
tasas(pd.date_range(start=fecha1, end=fecha2, freq='D'))
# Out:
# (Country
#  Afghanistan     584.849212
#  Albania         763.903813
#  Algeria         837.220934
#  Andorra          77.084358
#  Angola          229.063497
#                    ...
#  Venezuela      1494.180352
#  Vietnam        2488.157874
#  Yemen            36.102907
#  Zambia          813.095917
#  Zimbabwe        481.766390
#  Length: 180, dtype: float64,
#  Country
#  Afghanistan    26.435365
#  Albania        12.800462
#  Algeria        22.970450
#  Andorra         0.641327
#  Angola          5.587315
#                   ...
#  Venezuela      17.266150
#  Vietnam        51.664498
#  Yemen           7.146639
#  Zambia         12.900733
#  Zimbabwe       15.798593
#  Length: 180, dtype: float64,
#  Afghanistan    158.650937
#  Albania        277.225980
#  Algeria        238.360617
#  Andorra         33.050374
#  Angola          69.104228
#                    ...
#  Venezuela      512.652446
#  Vietnam         14.676882
#  Yemen            7.293144
#  Zambia         267.381284
#  Zimbabwe       103.709095
#  Length: 180, dtype: float64)

# %%
print(f"Los paises con la mayor y menor incidencia son: {tasas_inc_sorted.index[-1]} y {tasas_inc_sorted.index[0]}")
print(f"Los paises con la mayor y menor recuperacion son: {tasas_rec_sorted.index[-1]} y {tasas_rec_sorted.index[0]}")
print(f"Los paises con la mayor y menor mortalidad son: {tasas_mort_sorted.index[-1]} y {tasas_mort_sorted.index[0]}")
# Out:
# Los paises con la mayor y menor incidencia son: India y Tonga
# Los paises con la mayor y menor recuperacion son: India y Serbia
# Los paises con la mayor y menor mortalidad son: Brazil y Holy See

# %%
posicion_inc = tasas_inc_sorted.index.get_loc("Chile")
posicion_rec = tasas_rec_sorted.index.get_loc("Chile")
posicion_mort = tasas_mort_sorted.index.get_loc("Chile")


print(f"Chile se encuentra en la posicion {posicion_inc} de tasa de incidencia a nivel mundial")
print(f"Chile se encuentra en la posicion {posicion_rec} de tasa de recuperacion a nivel mundial")
print(f"Chile se encuentra en la posicion {posicion_mort} de tasa de mortalidad a nivel mundial")
# Out:
# Chile se encuentra en la posicion 157 de tasa de incidencia a nivel mundial
# Chile se encuentra en la posicion 164 de tasa de recuperacion a nivel mundial
# Chile se encuentra en la posicion 160 de tasa de mortalidad a nivel mundial

# %% [markdown]
# Ahora realice las siguientes gráficas de nube de punto
#
# - Tasa de incidencia Enero 2021 versus Tasa de incidencia Enero 2022.
# - Tasa de mortalidad Enero 2021 versus Tasa de incidencia Enero 2022.
#
# En cada una:
#
# - Utilice color para demarcar el [continente](https://www.kaggle.com/datasets/statchaitya/country-to-continent) de cada país.
# - Realice una anotación con el código del pais cercano a su punto: https://country-code.cl/es/.
# - Utilice un tamaño relativamente más grande para Chile.
# - Considere las buenas prácticas vistas en clases.

# %%
tasa_2021 = tasas(pd.date_range(start="1st of January of 2021", end="31th of January of 2021", freq='D'))[0]
tasa_2021.name = "tasa_2021"
tasa_2022 = tasas(pd.date_range(start="1st of January of 2022", end="31th of January of 2022", freq='D'))[0]
tasa_2022.name = "tasa_2022"

# %%
df_enero = pd.concat([tasa_2021, tasa_2022], axis=1)

# %%
df_enero.head()
# Out:
#              tasa_2021   tasa_2022
# Country
# Afghanistan  23.336516   68.955908
# Albania      29.157927  100.787666
# Algeria      44.854294   99.713081
# Andorra       3.898954   13.012818
# Angola        8.102827   40.095737

# %%
# !pip install pycountry_convert
# Out:
# Requirement already satisfied: pycountry_convert in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (0.7.2)
# Requirement already satisfied: repoze.lru>=0.7 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry_convert) (0.7)
# Requirement already satisfied: pytest-mock>=1.6.3 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry_convert) (3.10.0)
# Requirement already satisfied: pprintpp>=0.3.0 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry_convert) (0.4.0)
# Requirement already satisfied: wheel>=0.30.0 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry_convert) (0.40.0)
# Requirement already satisfied: pytest>=3.4.0 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry_convert) (7.3.1)
# Requirement already satisfied: pytest-cov>=2.5.1 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry_convert) (4.0.0)
# Requirement already satisfied: pycountry>=16.11.27.1 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry_convert) (22.3.5)
# Requirement already satisfied: setuptools in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pycountry>=16.11.27.1->pycountry_convert) (67.6.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.0.0)
# Requirement already satisfied: iniconfig in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (2.0.0)
# Requirement already satisfied: packaging in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (23.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (2.0.1)
# Requirement already satisfied: colorama in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (0.4.6)
# Requirement already satisfied: coverage[toml]>=5.2.1 in c:\users\nicolas\anaconda3\envs\info147\lib\site-packages (from pytest-cov>=2.5.1->pycountry_convert) (7.2.3)

# %%
import pycountry_convert as pc

def obtener_continente(country_name):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
        return country_continent_name
    except KeyError:
        return "unknow"

# %%
continentes = [obtener_continente(pais) for pais in df_merged.index]

# %%
df_enero["continente"] = continentes
df_enero["continente"]
# Out:
# Country
# Afghanistan             Asia
# Albania               Europe
# Algeria               Africa
# Andorra               Europe
# Angola                Africa
#                    ...
# Venezuela      South America
# Vietnam                 Asia
# Yemen                   Asia
# Zambia                Africa
# Zimbabwe              Africa
# Name: continente, Length: 180, dtype: object

# %%
df_enero.head()
# Out:
#              tasa_2021   tasa_2022 continente
# Country
# Afghanistan  23.336516   68.955908       Asia
# Albania      29.157927  100.787666     Europe
# Algeria      44.854294   99.713081     Africa
# Andorra       3.898954   13.012818     Europe
# Angola        8.102827   40.095737     Africa

# %%
df_enero["continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania', 'unknow'], dtype=object)

# %%
continent_colors = {'Asia': 'green', 'Europe': 'blue', 'Africa': 'orange', 
                    'North America': 'red', 'South America': 'purple', "Oceania": "black", "unknow": "gray"}

# %%
df_enero['color'] = df_enero['continente'].map(continent_colors)
df_enero.head()
# Out:
#              tasa_2021   tasa_2022 continente   color
# Country
# Afghanistan  23.336516   68.955908       Asia   green
# Albania      29.157927  100.787666     Europe    blue
# Algeria      44.854294   99.713081     Africa  orange
# Andorra       3.898954   13.012818     Europe    blue
# Angola        8.102827   40.095737     Africa  orange

# %%
# Obtener los códigos alpha-2 de los países
# %matplotlib ipympl
country_codes = {}
for country in df_enero.index:
    try:
        country_obj = pycountry.countries.search_fuzzy(country)[0]
        country_codes[country] = country_obj.alpha_2
    except LookupError:
        print(f"No se encontró el país {country} en la base de datos.")

# Crear el gráfico
fig, ax = plt.subplots(figsize=(10, 10))
pais="Chile"
pais_size=300
# Resto de los países
mask_resto = df_enero.index != pais
df_resto = df_enero[mask_resto]
ax.scatter(df_resto["tasa_2021"], df_resto["tasa_2022"], 
           c=df_resto["color"], alpha=0.4)

# País de interés
mask_pais = df_enero.index == pais
df_pais = df_enero[mask_pais]
ax.scatter(df_pais["tasa_2021"], df_pais["tasa_2022"], 
           c=df_pais["color"], alpha=0.4, s=pais_size, edgecolors='black')

# Anotar los códigos de los países
for country, code in country_codes.items():
    x = df_enero.loc[country, "tasa_2021"]
    y = df_enero.loc[country, "tasa_2022"]
    ax.annotate(code, (x, y), fontsize=7)

# Ajustar los ejes y el título
ax.set_xlabel("Tasa de incidencia Enero 2021")
ax.set_ylabel("Tasa de incidencia Enero 2022")
ax.set_title("Relación entre tasas de incidencia en enero de 2021 y 2022 por continente")

# Añadir leyenda
for continent, color in continent_colors.items():
    ax.scatter([], [], c=color, label=continent)
ax.legend(scatterpoints=1, frameon=False, labelspacing=1, loc="upper left",bbox_to_anchor=(0.75, 1.0))
# Out:
# No se encontró el país Laos en la base de datos.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tasa_m_2021 = tasas(pd.date_range(start="1th of January of 2021", end="31th of January of 2021", freq='D'))[1]
tasa_m_2021.name = "tasa_2021"

# %%
df_enero = pd.concat([tasa_m_2021, tasa_2022], axis=1)

# %%
df_enero["continente"] = continentes

# %%
df_enero['color'] = df_enero['continente'].map(continent_colors)
df_enero.head()
# Out:
#              tasa_2021   tasa_2022 continente   color
# Country
# Afghanistan   1.003845   68.955908       Asia   green
# Albania       0.551276  100.787666     Europe    blue
# Algeria       1.225068   99.713081     Africa  orange
# Andorra       0.039167   13.012818     Europe    blue
# Angola        0.188241   40.095737     Africa  orange

# %%
print(tasas(pd.date_range(start="1st of January of 2021", end="31th of January of 2021", freq='D'))[0])
tasas(pd.date_range(start="1st of January of 2021", end="31th of January of 2021", freq='D'))[1]
# Out:
# Country
# Afghanistan    23.336516
# Albania        29.157927
# Algeria        44.854294
# Andorra         3.898954
# Angola          8.102827
#                  ...
# Venezuela      51.827577
# Vietnam         0.671069
# Yemen           0.913753
# Zambia         15.533022
# Zimbabwe       10.995032
# Length: 180, dtype: float64
# Country
# Afghanistan    1.003845
# Albania        0.551276
# Algeria        1.225068
# Andorra        0.039167
# Angola         0.188241
#                  ...
# Venezuela      0.477312
# Vietnam        0.015150
# Yemen          0.265082
# Zambia         0.236750
# Zimbabwe       0.321327
# Length: 180, dtype: float64

# %%
# Obtener los códigos alpha-2 de los países
# %matplotlib ipympl
country_codes = {}
for country in df_enero.index:
    try:
        country_obj = pycountry.countries.search_fuzzy(country)[0]
        country_codes[country] = country_obj.alpha_2
    except LookupError:
        print(f"No se encontró el país {country} en la base de datos.")

# Crear el gráfico
fig, ax = plt.subplots(figsize=(10, 10))
pais="Chile"
pais_size=300
# grafico resto de los países
mask_resto = df_enero.index != pais
df_resto = df_enero[mask_resto]
ax.scatter(df_resto["tasa_2021"], df_resto["tasa_2022"], 
           c=df_resto["color"], alpha=0.4)

#grafico chile
mask_pais = df_enero.index == pais
df_pais = df_enero[mask_pais]
ax.scatter(df_pais["tasa_2021"], df_pais["tasa_2022"], 
           c=df_pais["color"], alpha=0.4, s=pais_size, edgecolors='black')

# Anotar los códigos de los países
for country, code in country_codes.items():
    x = df_enero.loc[country, "tasa_2021"]
    y = df_enero.loc[country, "tasa_2022"]
    ax.annotate(code, (x, y), fontsize=7)

# Ajustar los ejes y el título
ax.set_xlabel("Tasa de incidencia Enero 2021")
ax.set_ylabel("Tasa de incidencia Enero 2022")
ax.set_title("Relación entre tasas de incidencia en enero de 2021 y 2022 por continente")

# Añadir leyenda
for continent, color in continent_colors.items():
    ax.scatter([], [], c=color, label=continent)
ax.legend(scatterpoints=1, frameon=False, labelspacing=1, loc="upper left",bbox_to_anchor=(0.75, 1.0))
# Out:
# No se encontró el país Laos en la base de datos.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# En base a los rankings y gráficas de nube de punto analice y discuta sobre el caso de Chile considerando las siguientes preguntas guía:
#
# - ¿A qué países del mundo se parece más?
# - ¿A qué países de América Latina se parece más?
# - ¿A qué países de la [OCDE](https://es.wikipedia.org/wiki/Organizaci%C3%B3n_para_la_Cooperaci%C3%B3n_y_el_Desarrollo_Econ%C3%B3micos) se parece más?

# %%
df_rec_merged
# Out:
#              2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
# ...                          ...                  ...                  ...
# Venezuela                      0                    0                    0
# Vietnam                        0                    0                    0
# Yemen                          0                    0                    0
# Zambia                         0                    0                    0
# Zimbabwe                       0                    0                    0
#
#              2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
# ...                          ...                  ...                  ...
# Venezuela                      0                    0                    0
# Vietnam                        0                    0                    0
# Yemen                          0                    0                    0
# Zambia                         0                    0                    0
# Zimbabwe                       0                    0                    0
#
#              2020-01-28 00:00:00  2020-01-29 00:00:00  2020-01-30 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
# ...                          ...                  ...                  ...
# Venezuela                      0                    0                    0
# Vietnam                        0                    0                    0
# Yemen                          0                    0                    0
# Zambia                         0                    0                    0
# Zimbabwe                       0                    0                    0
#
#              2020-01-31 00:00:00  ...  2022-04-02 00:00:00
# Afghanistan                    0  ...                    0  \
# Albania                        0  ...                    0
# Algeria                        0  ...                    0
# Andorra                        0  ...                    0
# Angola                         0  ...                    0
# ...                          ...  ...                  ...
# Venezuela                      0  ...                    0
# Vietnam                        0  ...                    0
# Yemen                          0  ...                    0
# Zambia                         0  ...                    0
# Zimbabwe                       0  ...                    0
#
#              2022-04-03 00:00:00  2022-04-04 00:00:00  2022-04-05 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
# ...                          ...                  ...                  ...
# Venezuela                      0                    0                    0
# Vietnam                        0                    0                    0
# Yemen                          0                    0                    0
# Zambia                         0                    0                    0
# Zimbabwe                       0                    0                    0
#
#              2022-04-06 00:00:00  2022-04-07 00:00:00  2022-04-08 00:00:00
# Afghanistan                    0                    0                    0  \
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
# Angola                         0                    0                    0
# ...                          ...                  ...                  ...
# Venezuela                      0                    0                    0
# Vietnam                        0                    0                    0
# Yemen                          0                    0                    0
# Zambia                         0                    0                    0
# Zimbabwe                       0                    0                    0
#
#              2022-04-09 00:00:00  2022-04-10 00:00:00  Population (2020)
# Afghanistan                    0                    0           39074280
# Albania                        0                    0            2877239
# Algeria                        0                    0           43984569
# Andorra                        0                    0              77287
# Angola                         0                    0           33032075
# ...                          ...                  ...                ...
# Venezuela                      0                    0           28421581
# Vietnam                        0                    0           97490013
# Yemen                          0                    0           29935468
# Zambia                         0                    0           18468257
# Zimbabwe                       0                    0           14899771
#
# [180 rows x 811 columns]

# %% [markdown]
# ## Análisis comparativo (1.5pt)
#
# Construya una interfaz gráfica usando `ipywidgets` y `matplotlib` que permita realizar comparaciones entre las series de tiempo de COVID-19 de dos países seleccionados arbitrariamente. A modo de simplificación considere sólo los países de la [OCDE](https://es.wikipedia.org/wiki/Organizaci%C3%B3n_para_la_Cooperaci%C3%B3n_y_el_Desarrollo_Econ%C3%B3micos).
#
# Requerimientos:
#
# 1. La interfaz debe incluir controles para escoger dos países a partir de una lista.
# 1. La interfaz debe incluir tres [tabs](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#Tabs), el primero debe mostrar las series de tiempo de ambos países de los casos confirmados, el segundo la de recuperados y el tercero la de los decesos, respectivamente. Use una leyenda para indicar el nombre de los países.
# 1. La interfaz debe tener un control que permita escoger entre casos acumulados y casos nuevos. Hint: Para los casos nuevos pueden revisar la función [`diff`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.diff.html).
# 1. La interfaz debe tener un control que permita escoger entre valores absolutos y valores relativos (tasas por 100.000 habitantes).
# 1. La interfaz debe tener un control que permita escoger entre valores diarios y valores semanales. Para esto último se recomienda usar `groupby` con una [frecuencia lunes a lunes](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#anchored-offsets).

# %%
df_merged
df_rec_merged
df_m_merged
import ipywidgets as widgets
from IPython.display import clear_output
def graficar_casos_confirmados(pais1, pais2,tipo2,tipo3):
    
    plt.figure(figsize=(10, 6))
    #if(tipo1=="Casos Confirmados"):
    if(tipo3=="relativo"):
        if(tipo2=="acumulado"):
            
            plt.plot(df_merged.loc[pais1][:-1].diff()/100000, label=pais1) 
            plt.plot(df_merged.loc[pais2][:-1].diff()/100000, label=pais2)    
        else:
            plt.plot(df_merged.loc[pais1][:-1]/100000, label=pais1) 
            plt.plot(df_merged.loc[pais2][:-1]/100000, label=pais2)
    elif(tipo3=="absoluto"):
        if(tipo2=="acumulado"):    
            plt.plot(df_merged.loc[pais1][:-1].diff(), label=pais1) 
            plt.plot(df_merged.loc[pais2][:-1].diff(), label=pais2)
        else:
            plt.plot(df_merged.loc[pais1][:-1], label=pais1) 
            plt.plot(df_merged.loc[pais2][:-1], label=pais2)
    
def graficar_personas_recuperadas(pais1, pais2,tipo2,tipo3):
    
    plt.figure(figsize=(10, 6))       
    #elif(tipo1=="Personas Recuperadas"):
    if(tipo3=="relativo"):
        if(tipo2=="acumulado"):
            plt.plot(df_rec_merged.loc[pais1][:-1].diff()/100000, label=pais1) 
            plt.plot(df_rec_merged.loc[pais2][:-1].diff()/100000, label=pais2)    
        else:
            plt.plot(df_rec_merged.loc[pais1][:-1]/100000, label=pais1) 
            plt.plot(df_rec_merged.loc[pais2][:-1]/100000, label=pais2)
    elif(tipo3=="absoluto"):
        if(tipo2=="acumulado"):    
            plt.plot(df_rec_merged.loc[pais1][:-1].diff(), label=pais1) 
            plt.plot(df_rec_merged.loc[pais2][:-1].diff(), label=pais2)
        else:
            plt.plot(df_rec_merged.loc[pais1][:-1], label=pais1) 
            plt.plot(df_rec_merged.loc[pais2][:-1], label=pais2)
  
def graficar_cantidad_descesos(pais1, pais2,tipo2,tipo3):
    
    plt.figure(figsize=(10, 6))            
    #elif(tipo1=="Cantidad de descesos"): 
    if(tipo3=="relativo"):
        if(tipo2=="acumulado"):
            plt.plot(df_m_merged.loc[pais1][:-1].diff()/100000, label=pais1) 
            plt.plot(df_m_merged.loc[pais2][:-1].diff()/100000, label=pais2)    
        else:
            plt.plot(df_m_merged.loc[pais1][:-1]/100000, label=pais1) 
            plt.plot(df_m_merged.loc[pais2][:-1]/100000, label=pais2)
    elif(tipo3=="absoluto"):
        if(tipo2=="acumulado"):    
            plt.plot(df_m_merged.loc[pais1][:-1].diff(), label=pais1) 
            plt.plot(df_m_merged.loc[pais2][:-1].diff(), label=pais2)
        else:
            plt.plot(df_m_merged.loc[pais1][:-1], label=pais1) 
            plt.plot(df_m_merged.loc[pais2][:-1], label=pais2)           

    
paises= list(df_rec_merged.index)

ocde_codigos = ['AU', 'AT', 'BE', 'CA', 'CL', 'CZ', 'DK', 'EE', 'FI', 'FR', 'DE', 'GR', 'HU', 'IS', 'IR', 'IL', 'IT', 'JP', 'KR', 'LV', 'LT', 'LU', 'MX', 'NL', 'NZ', 'NO', 'PL', 'PT', 'SK', 'SI', 'ES', 'SE', 'CH', 'TR', 'GB', 'US']
ocde_paises=[]
for code in ocde_codigos:
   country = pycountry.countries.get(alpha_2=code)
   ocde_paises.append(country.name)
  
paises_ocde = []
for pais in paises:
    try:
        country = pycountry.countries.get(name=pais)
        if ((country.alpha_2 in ocde_codigos)):
            paises_ocde.append(pais)
    except:
        pass
paises_ocde.append("Iran")  
paises_ocde.sort()
print(paises_ocde)
relativo_absoluto=["relativo","absoluto"]
tipo_codigo=["acumulado","nuevos"]
#codigos_graficos=["Casos Confirmados","Personas Recuperadas","Cantidad de descesos"]
#codigos_graficos_widget=widgets.Dropdown(options=codigos_graficos,value=codigos_graficos[2],description="tipo de grafico")
tipo_codigos_widgets=widgets.Dropdown(options=tipo_codigo,value=tipo_codigo[0],description="Acumulado o Nuevo")
relativo_absoluto_widgets=widgets.Dropdown(options=relativo_absoluto,value=relativo_absoluto[0],description="Relativo o Absoluto")
pais1_widget = widgets.Dropdown(options=paises_ocde, value=paises_ocde[0], description='País 1:')
pais2_widget = widgets.Dropdown(options=paises_ocde, value=paises_ocde[1], description='País 2:')
#widgets.interact(graficar_paises,pais1=pais1_widget,pais2=pais2_widget,tipo1=codigos_graficos_widget,tipo2=tipo_codigos_widgets,tipo3=relativo_absoluto_widgets)

def on_button_clicked(b):
    if (tab.selected_index == 0):   
         
        graficar_casos_confirmados(pais1_widget.value, pais2_widget.value, tipo_codigos_widgets.value, relativo_absoluto_widgets.value)
    elif(tab.selected_index == 1):        
        graficar_personas_recuperadas(pais1_widget.value, pais2_widget.value, tipo_codigos_widgets.value, relativo_absoluto_widgets.value)
    elif(tab.selected_index == 2):
        graficar_cantidad_descesos(pais1_widget.value, pais2_widget.value, tipo_codigos_widgets.value, relativo_absoluto_widgets.value)
    
button = widgets.Button(description='Graficar')
button.on_click(on_button_clicked)
tab=widgets.Tab()
tab1 = widgets.VBox(children=[tipo_codigos_widgets, relativo_absoluto_widgets, pais1_widget, pais2_widget, button])
tab2 = widgets.VBox(children=[tipo_codigos_widgets, relativo_absoluto_widgets, pais1_widget, pais2_widget, button])
tab3 = widgets.VBox(children=[tipo_codigos_widgets, relativo_absoluto_widgets, pais1_widget, pais2_widget, button])
tab.children = [tab1, tab2, tab3]
tab.set_title(0, 'Casos Confirmados')
tab.set_title(1, 'Personas Recuperadas')
tab.set_title(2, 'Cantidad de descesos')



display(tab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_merged
#       2 df_rec_merged
#       3 df_m_merged
#
# NameError: name 'df_merged' is not defined

# %% [markdown]
# ## Dashboard interactivo (1.0pt)
#
# Implemente un *dashboard web* interactivo a partir de la interfaz desarrollada en el punto anterior utilizando la librería [voila](https://github.com/voila-dashboards/voila). Sirva su interfaz en la nube, para esto puede considerar los servicios gratuitos [binder](https://mybinder.org/) o [heroku](https://www.heroku.com/free). Revise la documentación de voila [con respecto a *deployment* en la nube](https://voila.readthedocs.io/en/stable/deploy.html) y este repositorio con [un ejemplo en base a heroku](https://github.com/voila-dashboards/voila-heroku).
#
# Escriba el link de su dashboard web a continuación:

# %% [markdown]
# ## Discusión final (1.0pt)

# %% [markdown]
# En base a su interfaz:
#
# 1. Describa en detalle la situación de Chile con respecto a la evolución temporal de las series de tiempo. Destaque patrones y comportamientos que considere relevantes. Compare lo que observa en las distintas series de tiempo.
# 1. Considerando la evolución a nivel de semana, conteste ¿En qué fechas ocurre un aumento o disminución notoria de los casos? ¿En qué fechas hay máximos y mínimos?
# 1. Considerando métricas que sean relativas compare el caso de Chile contra cinco países de la OCDE seleccionados por ustedes. Destaque semejanzas y diferencias considerando las cantidades y los posibles desfases temporales existentes.
